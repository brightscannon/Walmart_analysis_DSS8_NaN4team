# %% [markdown]
# # EDA - Walmart - preprocessing
# > # index
# ### 1. 데이터 불러오기 및 함수 호출
# ### 2. 사전 데이터정제 및 garbage값 제거 (근거 간략요약)
#     0) 3년기간동안 units가 모두 = 0 인 값 제거(존재하지않는 아이템값은 0이라고 가정한다)
#     2) 데이터열 자료형 최적화
#     3) 날씨코드구분
#     4) 전체데이터 조합
#     5) 날짜분할(년,월,일), 온도차, 컬럼생성

# %% [markdown]
# ---
# # 1. 데이터 불러오기 및 함수호출=========================

# %%
#주피터노트북 그래프설정

# %matplotlib inline
#주피터노트북에서 라인 아래에 보여지도록 설정

# %config InlineBackend.figure_formats = {'png','retina'} 
#png 이미지 압축기술설정, retina 그래프 해상도 2배 높히기

#그래프 한글폰트 설정
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc

#그래프 한글폰트 설정
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgunbd.ttf").get_name()
rc('font', family=font_name)
#음수처리
mpl.rcParams['axes.unicode_minus'] = False

# %%
import os
import datetime as dt
import numpy as np
import pandas as pd
import pandas_profiling as pdp
# Out:
# C:\Users\creal\Anaconda3\lib\site-packages\matplotlib\__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
#전체기후날씨데이터(weather.csv) 불러오기--------------------------
weather = pd.read_csv('weather.csv')
# weather["date"]=weather["date"].astype("datetime64[ns]") #-----열 선택하여 형변환
#지점-기후관측소 대조표(key.csv) 불러오기
map_key = pd.read_csv('key.csv')

#일일-지점-상품-판매량 정보(train.csv) 불러오기
store_data = pd.read_csv('train.csv')

#판매량 예측을 위한 지점정보(test.csv) 불러오기
test = pd.read_csv('test.csv')

# %%
# ★ 함수선언 ------------------------------------------------------
#-------날씨요소기준// 날짜-스테이션 데이터 도출함수
def weather_pivot(column_name):

    station_itm = pd.DataFrame(weather,columns=["station_nbr","date",column_name])

        # 스테이션별 피봇팅(테이블)
    station_value = station_itm.pivot("date","station_nbr",column_name)
    station_table = station_value.apply(pd.to_numeric, errors = 'coerce')

    return station_table
    

#--------날씨요소기준// 날짜별 스테이션(숫자형)날씨요소 평균 도출함수---------
def weather_mean(column_name):
    station_itm = pd.DataFrame(weather,columns=["date","station_nbr",column_name])
        # 데이터타입 숫자화(이거 안되면 에러나니까 꼭 타입정제부터 하자)
    temp_df = station_itm.replace(["M",None],np.NaN) #--특정문자 NaN으로 변환
    temp_df = temp_df.replace(["T","  T"],0.005)
    station_itm = temp_df.apply(pd.to_numeric, errors = 'ignore')
        # 평균구해넣기
    avg_df = station_itm.pivot_table(column_name,["date"], aggfunc=np.mean)
    avg_df = avg_df.apply(pd.to_numeric, errors = 'ignore')

    return avg_df


#--------날씨요소기준// 스테이션-전체날짜 날씨요소평균 도출함수---------
def station_mean(column_name):
    station_itm = pd.DataFrame(weather,columns=["station_nbr","date",column_name])
        # 데이터타입 숫자화(이거 안되면 에러나니까 꼭 타입정제부터 하자)
    temp_df = station_itm.replace(["M",None],np.NaN) #--특정문자 NaN으로 변환
    temp_df = temp_df.replace(["T","  T"],0.005)
    station_itm = temp_df.apply(pd.to_numeric, errors = 'ignore')
        # 평균구해넣기
    station_avg = station_itm.pivot_table(column_name,["station_nbr"], aggfunc=np.mean)
    station_avg = station_avg.apply(pd.to_numeric, errors = 'ignore')
    
    return station_avg

#=============================================================================

#------★★완전체 형변환 함수(M,T,__T,None)==> 있는열도 변환 가능
def type_change_numeric(df, ls = []): 
    #ls에 있는 column name은 numeric형으로 바꾸지 않는다.
    cols = df.columns
    for i in cols:
        if i in ls:
            continue 
        df = df.replace(["M",None],np.NaN)
        df = df.replace(["T","  T"],0.005)
        df[i] = pd.to_numeric(df[i], errors='coerce')
        
    return df

# %%
#weather_p에 사전정제자료 삽입(codesum은 추가정제필요)
weather_p = type_change_numeric(weather,["station_nbr","codesum","date"])
weather_p["date"] = pd.to_datetime(weather_p["date"])
weather_p["tdelta"] = weather_p["tmax"]-weather_p["tmin"]
weather_p["RA"] = weather_p['codesum'].str.contains("RA")== True
weather_p["BR"] = weather_p['codesum'].str.contains("BR")== True
weather_p["HZ"] = weather_p['codesum'].str.contains("HZ")== True
weather_p["TS"] = weather_p['codesum'].str.contains("TS")== True
weather_p["FG"] = weather_p['codesum'].str.contains("FG")== True
weather_p["SN"] = weather_p['codesum'].str.contains("SN")== True

# %%
weather_p.dtypes
# Out:
# station_nbr             int64
# date           datetime64[ns]
# tmax                  float64
# tmin                  float64
# tavg                  float64
# depart                float64
# dewpoint              float64
# wetbulb               float64
# heat                  float64
# cool                  float64
# sunrise               float64
# sunset                float64
# codesum                object
# snowfall              float64
# preciptotal           float64
# stnpressure           float64
# sealevel              float64
# resultspeed           float64
# resultdir             float64
# avgspeed              float64
# tdelta                float64
# RA                       bool
# BR                       bool
# HZ                       bool
# TS                       bool
# FG                       bool
# SN                       bool
# dtype: object

# %% [markdown]
# ---
# # 2. 사전 데이터정제 및 Garbage값 제거===================

# %%
# 0) units = 0 인값 제거한 데이터프레임 만들기 (주의! units=0인값이 전혀 나오지 않게됩니다.)
 #  └-- 장점으로는 계산이 빠르다 + 없는값을 제외하고 볼 수 있어서 그래프 그릴때 편하다. 
store_df = store_data[store_data["units"]!=0]

# %%
#   └--units = 0인값을 다시 복구하고 싶을시 사용하시오 (주의! 뭘하든 오래걸리게됩니다.)
store_df = store_data

# %%
# 1) 데이터 형변환(날짜 및 숫자)
import time

store_df["date"] = pd.to_datetime(store_df["date"])
weather_p["date"] = pd.to_datetime(weather_p["date"])
# Out:
# C:\Users\creal\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# 4) 전체데이터 조합 merge
#- 1. store_data에 스테이션 넘버 부여
result_df = store_df.merge(map_key, left_on="store_nbr", right_on="store_nbr" )
cols = ['date', 'store_nbr', 'station_nbr', 'item_nbr', 'units']
new_df = result_df[cols] #열 위치변경된 것들
#- 2. 종합세팅
all_set = new_df.merge(weather_p, left_on=["date","station_nbr"], right_on=["date","station_nbr"] )

# %%
# 데이터타입 날짜화 및 int화(이거 안되면 에러나니까 꼭 타입정제부터 하자)
all_set["date"]=all_set["date"].astype("datetime64[ns]") #-----열 선택하여 형변환
temp_df = type_change_numeric(all_set,["date","store_nbr","item_nbr","units","station_nbr","codesum"])

# %%
master = all_set.sort_values(["date","store_nbr","item_nbr"])

# %%
#날짜 분해 및 데이터정제

master['year'] = master['date'].dt.year
master['month'] = master['date'].dt.month
master['day'] = master['date'].dt.day
master['DOW']= master['date'].dt.dayofweek
master['SS']= (master['month']//3)%4 
#ss는 SeaSon의 약자로 0겨울 1봄 2여름 3가을 이다.

# %%
master[master["month"]==12]
# 89152  2013-12-31         37           13        45     33  55.0  27.0  41.0
# 89153  2013-12-31         37           13        53      1  55.0  27.0  41.0
# 9602   2013-12-31         38           14         9     61  56.0  21.0  39.0
# 9603   2013-12-31         38           14        45     94  56.0  21.0  39.0
# 9604   2013-12-31         38           14        52      1  56.0  21.0  39.0
# 115474 2013-12-31         39            8         9      4  50.0  38.0  44.0
# 115475 2013-12-31         39            8        36      9  50.0  38.0  44.0
# 89154  2013-12-31         40           13         5     36  55.0  27.0  41.0
# 89155  2013-12-31         40           13        45     61  55.0  27.0  41.0
# 89156  2013-12-31         40           13        55      5  55.0  27.0  41.0
# 9605   2013-12-31         42           14         5      5  56.0  21.0  39.0
# 9606   2013-12-31         42           14        45     46  56.0  21.0  39.0
#
#         depart  dewpoint ...     BR     HZ     TS     FG     SN  year  month  \
# 961        NaN      18.0 ...   True   True  False  False   True  2012     12
# 962        NaN      18.0 ...   True   True  False  False   True  2012     12
# 963        NaN      18.0 ...   True   True  False  False   True  2012     12
# 964        NaN      18.0 ...   True   True  False  False   True  2012     12
# 6486      20.0      52.0 ...   True  False  False  False  False  2012     12
# 6487      20.0      52.0 ...   True  False  False  False  False  2012     12
# 14798      NaN      50.0 ...   True  False  False  False  False  2012     12
# 14799      NaN      50.0 ...   True  False  False  False  False  2012     12
# 14800      NaN      50.0 ...   True  False  False  False  False  2012     12
# 21320      NaN      37.0 ...   True   True  False  False  False  2012     12
# 21321      NaN      37.0 ...   True   True  False  False  False  2012     12
# 21322      NaN      37.0 ...   True   True  False  False  False  2012     12
# 21323      NaN      37.0 ...   True   True  False  False  False  2012     12
# 29489      NaN      59.0 ...   True  False  False  False  False  2012     12
# 29490      NaN      59.0 ...   True  False  False  False  False  2012     12
# 29491      NaN      59.0 ...   True  False  False  False  False  2012     12
# 6488      20.0      52.0 ...   True  False  False  False  False  2012     12
# 6489      20.0      52.0 ...   True  False  False  False  False  2012     12
# 37760     22.0      64.0 ...  False  False  False  False  False  2012     12
# 37761     22.0      64.0 ...  False  False  False  False  False  2012     12
# 41931     20.0      63.0 ...  False  False  False  False  False  2012     12
# 41932     20.0      63.0 ...  False  False  False  False  False  2012     12
# 41933     20.0      63.0 ...  False  False  False  False  False  2012     12
# 49821      NaN      57.0 ...  False  False  False  False  False  2012     12
# 49822      NaN      57.0 ...  False  False  False  False  False  2012     12
# 49823      NaN      57.0 ...  False  False  False  False  False  2012     12
# 49824      NaN      57.0 ...  False  False  False  False  False  2012     12
# 29492      NaN      59.0 ...   True  False  False  False  False  2012     12
# 29493      NaN      59.0 ...   True  False  False  False  False  2012     12
# 29494      NaN      59.0 ...   True  False  False  False  False  2012     12
# ...        ...       ... ...    ...    ...    ...    ...    ...   ...    ...
# 56293      NaN      19.0 ...  False  False  False  False  False  2013     12
# 56294      NaN      19.0 ...  False  False  False  False  False  2013     12
# 89148      NaN      17.0 ...  False  False  False  False  False  2013     12
# 89149      NaN      17.0 ...  False  False  False  False  False  2013     12
# 89150      NaN      17.0 ...  False  False  False  False  False  2013     12
# 106739     2.0      18.0 ...  False  False  False  False  False  2013     12
# 106740     2.0      18.0 ...  False  False  False  False  False  2013     12
# 56295      NaN      19.0 ...  False  False  False  False  False  2013     12
# 56296      NaN      19.0 ...  False  False  False  False  False  2013     12
# 56297      NaN      19.0 ...  False  False  False  False  False  2013     12
# 117860     NaN       4.0 ...  False  False  False  False  False  2013     12
# 117861     NaN       4.0 ...  False  False  False  False  False  2013     12
# 117862     NaN       4.0 ...  False  False  False  False  False  2013     12
# 117863     NaN       4.0 ...  False  False  False  False  False  2013     12
# 113303    -5.0      23.0 ...  False  False  False  False  False  2013     12
# 113304    -5.0      23.0 ...  False  False  False  False  False  2013     12
# 113305    -5.0      23.0 ...  False  False  False  False  False  2013     12
# 89151      NaN      17.0 ...  False  False  False  False  False  2013     12
# 89152      NaN      17.0 ...  False  False  False  False  False  2013     12
# 89153      NaN      17.0 ...  False  False  False  False  False  2013     12
# 9602       2.0      22.0 ...  False  False  False  False  False  2013     12
# 9603       2.0      22.0 ...  False  False  False  False  False  2013     12
# 9604       2.0      22.0 ...  False  False  False  False  False  2013     12
# 115474     NaN       NaN ...  False  False  False  False  False  2013     12
# 115475     NaN       NaN ...  False  False  False  False  False  2013     12
# 89154      NaN      17.0 ...  False  False  False  False  False  2013     12
# 89155      NaN      17.0 ...  False  False  False  False  False  2013     12
# 89156      NaN      17.0 ...  False  False  False  False  False  2013     12
# 9605       2.0      22.0 ...  False  False  False  False  False  2013     12
# 9606       2.0      22.0 ...  False  False  False  False  False  2013     12
#
#         day  DOW  SS
# 961       1    5   0
# 962       1    5   0
# 963       1    5   0
# 964       1    5   0
# 6486      1    5   0
# 6487      1    5   0
# 14798     1    5   0
# 14799     1    5   0
# 14800     1    5   0
# 21320     1    5   0
# 21321     1    5   0
# 21322     1    5   0
# 21323     1    5   0
# 29489     1    5   0
# 29490     1    5   0
# 29491     1    5   0
# 6488      1    5   0
# 6489      1    5   0
# 37760     1    5   0
# 37761     1    5   0
# 41931     1    5   0
# 41932     1    5   0
# 41933     1    5   0
# 49821     1    5   0
# 49822     1    5   0
# 49823     1    5   0
# 49824     1    5   0
# 29492     1    5   0
# 29493     1    5   0
# 29494     1    5   0
# ...     ...  ...  ..
# 56293    31    1   0
# 56294    31    1   0
# 89148    31    1   0
# 89149    31    1   0
# 89150    31    1   0
# 106739   31    1   0
# 106740   31    1   0
# 56295    31    1   0
# 56296    31    1   0
# 56297    31    1   0
# 117860   31    1   0
# 117861   31    1   0
# 117862   31    1   0
# 117863   31    1   0
# 113303   31    1   0
# 113304   31    1   0
# 113305   31    1   0
# 89151    31    1   0
# 89152    31    1   0
# 89153    31    1   0
# 9602     31    1   0
# 9603     31    1   0
# 9604     31    1   0
# 115474   31    1   0
# 115475   31    1   0
# 89154    31    1   0
# 89155    31    1   0
# 89156    31    1   0
# 9605     31    1   0
# 9606     31    1   0
#
# [7736 rows x 35 columns]

# %% [markdown]
# ---
# # 3. 데이터 column간 유사성, 상관성 분석

# %%
#----------이제 특정 함수를 써보자!

#1. 이슬점온도
station_dewpoint = weather_pivot("dewpoint")
station_dewpoint_avg = weather_mean("dewpoint")

#2. 하루평균온도
station_temp = weather_pivot("tavg")
station_temp_avg = weather_mean("tavg")

#3. 하루평균 바람세기
station_speed = weather_pivot("avgspeed")
station_speed_avg = weather_mean("avgspeed")
station_speed_eachavg = station_mean("avgspeed")

#4. 기압도
station_pressure = weather_pivot("stnpressure")
station_pressure_avg = weather_mean("stnpressure")
station_pressure_eachavg = station_mean("stnpressure") #개별 스테이션별 평균 기압

#5. 이상기후온도
station_depart = weather_pivot("depart")
station_depart_avg = weather_mean("depart")

#6. 적셜량
station_snow = weather_pivot("snowfall")
station_snow_avg = weather_mean("snowfall")
station_snow_eachavg = station_mean("snowfall") #개별 스테이션별 평균 적설량

#7. 강우량
station_rain = weather_pivot("preciptotal")
station_rain_avg = weather_mean("preciptotal")
station_rain_eachavg = station_mean("preciptotal") #개별 스테이션별 평균 적설량

#8. 바람방향
station_dir = weather_pivot("resultdir")
station_dir_avg = weather_mean("resultdir")
station_dir_eachavg = station_mean("resultdir")

# %%
# 스토어별 아이템 총 판매량
store_item = new_df.pivot_table("units","store_nbr","item_nbr", aggfunc=np.sum)
# avg_df = station_itm.pivot_table(column_name,["date"], aggfunc=np.mean)
store_item
# Out:
# item_nbr     1       2      3      4        5        6      7        8    \
# store_nbr
# 1            NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 2            NaN     NaN    NaN    NaN  55104.0      NaN    NaN      NaN
# 3            NaN  1083.0    NaN    NaN  56663.0      NaN    NaN      NaN
# 4            NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 5            NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 6            NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 7            NaN     NaN    NaN    NaN  62230.0      NaN  721.0      NaN
# 8            NaN     NaN    NaN    NaN  32647.0      NaN    NaN      NaN
# 9            NaN     NaN    NaN    NaN  45024.0      NaN    NaN      NaN
# 10           NaN     NaN    NaN    NaN  61866.0      NaN    NaN      NaN
# 11           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 12           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 13           NaN     NaN    NaN    NaN  67241.0      NaN    NaN      NaN
# 14           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 15           NaN     NaN    NaN    NaN  64522.0      NaN    NaN      NaN
# 16           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 17           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 18           NaN     NaN    NaN    NaN  16565.0      NaN    NaN      NaN
# 19           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 20           NaN     NaN    NaN    NaN  71034.0      NaN    NaN      NaN
# 21           NaN     NaN    NaN    NaN  41641.0      NaN    NaN      NaN
# 22           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 23           NaN     NaN    NaN    NaN  28810.0      NaN    NaN      NaN
# 24           NaN     NaN    NaN    NaN      NaN  41398.0    NaN      NaN
# 25           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 26           NaN  1482.0    NaN    NaN  43448.0      NaN    NaN      NaN
# 27           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 28           NaN   704.0    NaN    NaN  33338.0      NaN    NaN      NaN
# 29           NaN     NaN    NaN    NaN      NaN      NaN    NaN  30345.0
# 30           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 31           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 32           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 33           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 34           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 35           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 36         778.0     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 37           NaN     NaN    NaN    NaN  50063.0      NaN    NaN      NaN
# 38           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 39           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 40           NaN     NaN    NaN    NaN  48454.0      NaN    NaN      NaN
# 41           NaN     NaN    NaN    NaN      NaN      NaN    NaN      NaN
# 42           NaN     NaN    NaN    NaN  35178.0      NaN    NaN      NaN
# 43           NaN     NaN  675.0    NaN      NaN      NaN    NaN      NaN
# 44           NaN     NaN    NaN    NaN  32834.0      NaN    NaN      NaN
# 45           NaN     NaN    NaN  348.0      NaN      NaN    NaN      NaN
#
# item_nbr        9      10   ...     102    103    104    105   106    107  \
# store_nbr                   ...
# 1           27396.0    NaN  ...     NaN    NaN    NaN    NaN   NaN    NaN
# 2               NaN    NaN  ...     NaN    NaN    NaN    NaN   NaN    NaN
# 3               NaN    NaN  ...    31.0    NaN    NaN    NaN   NaN    NaN
# 4          117123.0    NaN  ...     NaN    NaN    NaN    NaN   NaN    NaN
# 5               NaN    NaN  ...     NaN    NaN    NaN  100.0   NaN    NaN
# 6           50431.0    NaN  ...     NaN    NaN    NaN    NaN   NaN  534.0
# 7               NaN    NaN  ...     NaN    NaN    NaN    NaN   NaN    NaN
# 8               NaN    NaN  ...     NaN    NaN    NaN    NaN   NaN    NaN
# 9               NaN  745.0  ...     NaN    NaN    NaN   73.0   NaN    NaN
# 10              NaN    NaN  ...     NaN    NaN    NaN    NaN   NaN    NaN
# 11          34103.0    NaN  ...     NaN    NaN    NaN    NaN   NaN    NaN
# 12              NaN    NaN  ...     NaN    NaN    NaN    NaN   NaN    NaN
# 13              NaN    NaN  ...     NaN    NaN   92.0    NaN   NaN    NaN
# 14          12164.0    NaN  ...     NaN    NaN    NaN    NaN   NaN    NaN
# 15              NaN    NaN  ...     NaN    NaN    NaN    NaN   NaN    NaN
# 16              NaN    NaN  ...     NaN    NaN    NaN    NaN   NaN    NaN
#
NaN     ...         NaN    NaN    NaN   NaN    NaN
# 43              NaN    NaN     ...         NaN    NaN   72.0   NaN    NaN
# 44              NaN    NaN     ...         NaN    NaN   83.0   NaN    NaN
# 45          15833.0    NaN     ...         NaN    NaN    NaN   NaN    NaN
# 99             17.0    1.0     ...         1.0    4.0    6.0   2.0    1.0
#
# item_nbr      108     109     110    111  sales_items
# store_nbr
# 1             NaN     NaN     NaN    NaN            8
# 2             NaN     NaN     NaN    NaN            5
# 3             NaN  1394.0     NaN    NaN            6
# 4             NaN     NaN     NaN    NaN            7
# 5             NaN     NaN     NaN    NaN            6
# 6             NaN     NaN     NaN    NaN            4
# 7             NaN     NaN     NaN    NaN            5
# 8             NaN     NaN     NaN    NaN            6
# 9             NaN     NaN     NaN    NaN            6
# 10            NaN     NaN     NaN    NaN            5
# 11            NaN     NaN  1402.0    NaN            6
# 12            NaN     NaN     NaN    NaN            5
# 13            NaN     NaN     NaN    NaN            5
# 14            NaN     NaN     NaN    NaN            8
# 15            NaN     NaN     NaN    NaN            8
# 16            NaN     NaN     NaN    NaN            8
# 17            NaN     NaN     NaN    NaN            4
# 18            NaN     NaN     NaN    NaN            4
# 19            NaN     NaN     NaN    NaN            8
# 20            NaN     NaN     NaN    NaN            6
# 21            NaN  2814.0     NaN    NaN            4
# 22            NaN     NaN     NaN    NaN            6
# 23            NaN     NaN     NaN    NaN            4
# 24            NaN     NaN     NaN    NaN            5
# 25            NaN     NaN     NaN    NaN            7
# 26            NaN     NaN     NaN    NaN            3
# 27            NaN     NaN     NaN    NaN            5
# 28            NaN     NaN     NaN    NaN            4
# 29            NaN     NaN     NaN    NaN            4
# 30            NaN     NaN     NaN    NaN            6
# 31            NaN     NaN     NaN    NaN            6
# 32            NaN     NaN     NaN    NaN            7
# 33            NaN     NaN     NaN    NaN            5
# 34            NaN     NaN     NaN    NaN            6
# 35            NaN     NaN     NaN    NaN            8
# 36            NaN     NaN     NaN    NaN            4
# 37            NaN     NaN     NaN    NaN            7
# 38            NaN     NaN     NaN    NaN            6
# 39            NaN     NaN     NaN  254.0            4
# 40            NaN     NaN     NaN    NaN            7
# 41         2045.0     NaN     NaN    NaN            6
# 42            NaN     NaN     NaN    NaN            3
# 43            NaN     NaN     NaN    NaN            6
# 44            NaN     NaN     NaN    NaN            6
# 45            NaN     NaN     NaN    NaN            6
# 99            1.0     2.0     1.0    1.0           45
#
# [46 rows x 112 columns]

# %% [markdown]
# ### - 아이템과 스토어의 판매 관계

# %%
plt.figure(figsize=(12,8))
X = range(1,len(store_item["sales_items"]))
plt.title("3년간 스토어별 아이템중 1번이라도 판매된 종류의 갯수")
plt.bar(X,store_item["sales_items"][:45],label="sales_item")

plt.show()

# %%
plt.figure(figsize=(12,8))
X = range(1,len(store_item.T[99]))
plt.title("특정아이템을 판매하는 스토어의 수")
plt.bar(X,store_item.T[99][:111],label="sales_item")

plt.xticks(range(0,115,5))
plt.yticks(range(0,40,2))
plt.grid(alpha = 0.25)

plt.show()

# %% [markdown]
# ### - 전체기준 X아이템넘버/Y판매갯수 추이

# %%
# 스토어, 아이템, 판매량(크기), 요일
plt.figure(figsize=(12,12))
x = master["item_nbr"]
y1 = master["store_nbr"]
# y2 = master["DOW"]
y3 = master["units"]
plt.grid(10)
plt.title("스토어별 아이템의 판매량(점크기)")
plt.scatter(x, y1, s=y3, alpha=0.1)
plt.show()
